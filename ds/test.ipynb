# %%
from message_list import Message_list
import utils

# %%
# 不设定系统提示词
message_list=Message_list()

# 设定系统提示词
# message_list=Message_list(system_prompt="your system prompt")

# %%
# 对话
content="hi"
utils.get_response(message_list,content)
# Out:
# Hello! How can I assist you today?
# assistant :
#  Hello! How can I assist you today?

# %%
# 展示历史记录
message_list.show_list()
# Out:
# system :
#  You are a helpful assistant.
#
# user :
#  hi
#
# assistant :
#  Hello! How can I assist you today?
